# %% [markdown]
# # 파이썬 프로그래밍
#
# ---
#
# 파이썬 인터프리터
# - pyhon interpreter
#
# 파이참(통합개발환경(IDE))
# - PyCharm
#
# 코멘트
# ####  #주석 : 개발자들 간의 가독성을 위한 메모
# - 복잡한 코드 설명
# - 코드와는 별개임
#
# 프로그래밍
# - 계산한 수식들을 프로그램에 알려주는 것
#
# 자료형(Data type)
#
# - 정수(Integer) : 2
#
# - 소수(Floting Point) : 2.0
#
# - 문자열(String) : "2"
#
# - 불린형(Boolean) : 참과 거짓(True or False)
#
# 스마트폰 : 하드웨어, 소프트웨어, 통신 등
#
# #### 추상화
# 복잡한 내용을 숨기고 주요 기능에만 신경 씀
# - 변수(Variable) = 값을 저장하는 것
# - 함수(Function) :  내장함수(기본 제공하는 함수)
#   - def 함수이름():
#   - 파라미터 : 함수에 값을 넘겨주는 것
#   - return : 돌려준다
# -

# %%
print(3*4)
print(5*7)
print(15-3)
# Out:
# 12
# 35
# 12

# %%
print(4990)
print(4990 * 2)
print(4990*3+1490*2+1250*2)
# Out:
# 4990
# 9980
# 20450

# %%
burger_price = 4990
coke_price = 1490
drink_price = 1250

print(burger_price*2+coke_price*2+drink_price*2)
# Out:
# 15460

# %%
def hello():
  print("hello!")
  print("어서오세요")

hello()
# Out:
# hello!
# 어서오세요

# %%
def hello(name):
  print("hello!")
  print(name)
  print("어서오세요")

hello("park")
# Out:
# hello!
# park
# 어서오세요

# %%
def print_sum(a, b, c):
  print(a+b+c)

print_sum(1, 3, 5)
print_sum(4, 7, 10)
# Out:
# 9
# 21

# %%
def get_square(x):
  return x*x

print(get_square(3))
# Out:
# 9

# %%
def get_square(x):
  return x*x

y = get_square(3)
print(y)
# Out:
# 9
