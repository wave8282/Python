# %% [markdown]
# 객체 지향 프로그래밍
#
# ---
#
#  * 파이썬은 순수 객체 지향 언어
#
# 파이썬의 모든 것이 객체, 모든 것들이 클래스의 인스턴스
#
# 프로그램을 객체들과 객체들의 소통을 의미
# 1. 객체 : 속성과 행동
#   - 무엇이든 객체가 될수 있음
# 2. 객체지향적으로 설계 - 모델링했다
#
# 3. 객체 지향 프로그래밍으로 프로그램을 만들려면
#     1. 프로그램에 어떤 객체들이 필요할지 정하기
#     2. 객체들의 속성과 행동을 정하기
#     3. 객체들이 서로 어떻게 소통할지 정하기
#
#
# 클래스와 인스턴스
# 1. User 객체
# - 속성(이름, 이메일주소 등)과 객체(자기소개하기, 팔로우하기)
#
# ex) 객체의 틀(붕어빵 틀) = 클래스
#
# ex) 클래스로 인스턴스를 만든다(객체를 만든다)
#
# 인스턴스변수를 사용하기 위해서는 반드시 사용 전 정의하기
#
# 객체 = 속성과 행동
# - 속성 -> 변수
# - 행동 -> 메소드
#
# 메소드의 종류
# 1. 인스턴스 메소드
# - 인스턴스 메소드의 특별한 규칙
#     - 인스턴스 이름.메소드이름()
#     - 인스턴스 이름으로 함수를 호출하면 자동으로 파라미터 출력해줌
# *self
#     - 인스턴스 메소드의 첫 번째 파라미터를 self를 권장
#
# 특수 메소드
# - 특정 상황에서 자동으로 호출되는 메소드
# - __init__는 인스턴스가 생성될 때 자동으로 호출
# - 생성과 초기화를 한번에 할 수 있는 장점
#
# - __str__ : 더블 언더스코어 메소드, 던더 에스티알
#     - print()함수 호출이 자동으로 호출
#     -  원하는 정보를 나오게 함
#
# 인스턴스 자신만의 속성 -> 인스턴수 변수
#
# 클래스 변수 -> 같은 클래스의 인스턴스들이 서로 공유
#
# 같은 이름의 클래스 변수와 같은 이름의 인스턴스 변수가 있으면 인스턴스 변수가 읽어진다
#
#
# 데코레이터
# - 파라미터로 받은 함수를 꾸며서 새로운 함수 리턴
# - @add_print_to 함수를 이 함수로 꾸며주라는 뜻
#
# 데코레이터의 쓸모
# - 중복되는 부분 데코레이터로 코드 깔끔하게 만듬
# - @ 데코레이터구나 새로운 기능을 준다
#
# 2. 클래스 메소드 - 클래스변수의 값을 읽거나 설정하는 메소드
# - 첫 번째 파라미터의 이름은 꼭 cls 쓰기
#
#
# 인스턴스 메소드 : 인스턴스 변수
#
# 클래스 메소드 : 클래스 변수
#
# 인스턴스 메소드 : 인스턴스 변수, 클래스 변수 모두 사용 가능
#
# 클래스 메소드는 인스턴스 변수 사용 불가
#
# 3. 정적 메소드
# - 인스턴스 변수와 클래스 변수를 전혀 다루지 않는 메소드
# - is_valid_email = 정적 메소드
# - 아무 변수도 사용하지 않음
#
# ##### 파이썬은 순수 객체 지향 언어
#
# - 가변 타입 객체 - 속성 변경 가능
#   - 리스트 [1,2,4], 딕셔너리(직접 작성하는 클래스)
# - 불변 타입 객체 - 속성 변경 불가
#   - 튜플 (1,2,3)
#   - 불린, 정수, 실수, 문자열
#
#
# 모듈 : 변수, 함수, 클래스 등을 모아놓은 파일

# %%
class User:
  def say_hello(some_user):
    print("안녕하세요 저는 {}입니다".format(some_user.name))
  pass

user1 = User()
user2 = User()
user3 = User()

user1.name = "김대위"
user1.email = "sacacs.kr"
user1.password = "11234"

user2.name = "대위"
user2.email = "sacacs.kr"
user2.password = "11234"

user3.name = "위"
user3.email = "sacacs.kr"
user3.password = "11234"

print(user1.name)
print(user1.email)

User.say_hello(user1)
User.say_hello(user2)
User.say_hello(user3)
user1.say_hello()
# Out:
# 김대위
# sacacs.kr
# 안녕하세요 저는 김대위입니다
# 안녕하세요 저는 대위입니다
# 안녕하세요 저는 위입니다
# 안녕하세요 저는 김대위입니다

# %%
class User:
  def say_hello(self):
     print("안녕하세요 저는 {}입니다".format(self.name))

     def login(self, my_email, my_password):
       if(self.my_email == my_email and self.my_password == my_password):
         print("로그인 성공, 환영합니다")

# %%
def check_name(self, name):
  return self.name == name

ser1 = User()
user2 = User()
user3 = User()

user1.name = "김대위"
user1.email = "sacacs.kr"
user1.password = "11234"

user2.name = "대위"
user2.email = "sacacs.kr"
user2.password = "11234"

user3.name = "위"
user3.email = "sacacs.kr"
user3.password = "11234"

# %%
class User:
    # initialize 메소드를 여기 작성하세요
    # def initialize...
    def initialize(self, name, email, password):
        self.name = name
        self.email = email
        self.password = password

user1 = User()
user1.initialize("Young", "young@codeit.kr", "123456")

user2 = User()
user2.initialize("Yoonsoo", "yoonsoo@codeit.kr", "abcdef")

user3 = User()
User.initialize(user3, "Taeho", "taeho@codeit.kr", "123abc")

user4 = User()
User.initialize(user4, "Lisa", "lisa@codeit.kr", "abc123")



print(user1.name, user1.email, user1.password)
print(user2.name, user2.email, user2.password)
print(user3.name, user3.email, user3.password)
print(user4.name, user4.email, user4.password)
# Out:
# Young young@codeit.kr 123456
# Yoonsoo yoonsoo@codeit.kr abcdef
# Taeho taeho@codeit.kr 123abc
# Lisa lisa@codeit.kr abc123

# %%
class User:

    def __init__(self, name, email, password):
        self.name = name
        self.email = email
        self.password = password


user1 = User("Young", "young@codeit.kr", "123456")

user2 = User("Yoonsoo","yoonsoo@codeit.kr", "abcdef")

user3 = User("Taeho", "taeho@codeit.kr", "123abc")

user4 = User("Lisa", "lisa@codeit.kr", "abc123")


print(user1.name, user1.email, user1.password)
print(user2.name, user2.email, user2.password)
print(user3.name, user3.email, user3.password)
print(user4.name, user4.email, user4.password)
# Out:
# Young young@codeit.kr 123456
# Yoonsoo yoonsoo@codeit.kr abcdef
# Taeho taeho@codeit.kr 123abc
# Lisa lisa@codeit.kr abc123

# %%
class User:
    # 인스턴스 변수 설정
    def __init__(self, name, email, password):
        self.name = name
        self.email = email
        self.password = password

        self.following_list = []    # 이 유저가 팔로우하는 유저 리스트
        self.followers_list = []    # 이 유저를 팔로우하는 유저 리스트

    # 팔로우
    def follow(self, another_user):
        self.following_list.append(another_user)
        another_user.followers_list.append(self)

    # 내가 몇 명을 팔로우하는지 리턴
    def num_following(self):
        return len(self.following_list)

    # 나를 몇 명이 팔로우하는지 리턴
    def num_followers(self):
        return len(self.followers_list)

# 유저들 생성
user1 = User("Young", "young@codeit.kr", "123456")
user2 = User("Yoonsoo", "yoonsoo@codeit.kr", "abcdef")
user3 = User("Taeho", "taeho@codeit.kr", "123abc")
user4 = User("Lisa", "lisa@codeit.kr", "abc123")

# 유저마다 서로 관심 있는 유저를 팔로우
user1.follow(user2)
user1.follow(user3)
user2.follow(user1)
user2.follow(user3)
user2.follow(user4)
user4.follow(user1)

# 유저 이름, 자신의 팔로워 수, 자신이 팔로우하는 사람 수를 출력합니다
print(user1.name, user1.num_followers(), user1.num_following())
print(user2.name, user2.num_followers(), user2.num_following())
print(user3.name, user3.num_followers(), user3.num_following())
print(user4.name, user4.num_followers(), user4.num_following())
# Out:
# Young 2 2
# Yoonsoo 1 3
# Taeho 2 0
# Lisa 1 1

# %%
def __str__(self):
  return "사용자 : {}, 이메일 : {}, 팔로워 : {}, 팔로잉 : {}".format(self.name, self.email, len(self.followers_list), len(self.following_list))

# %%
class User:
  count = 0

  def __init__(self, name, email, password):
        self.name = name
        self.email = email
        self.password = password

        User.count += 1

user1 = User("Young", "young@codeit.kr", "123456")
user2 = User("Yoonsoo", "yoonsoo@codeit.kr", "abcdef")
user3 = User("Taeho", "taeho@codeit.kr", "123abc")
user4 = User("Lisa", "lisa@codeit.kr", "abc123")


User.count = 5
print(User.count)
print(user1.count)
print(user2.count)
print(user3.count)
# Out:
# 5
# 5
# 5
# 5

# %%
@classmethod
def number_of_users(cls):
  print("총 유저 수는: {}입니다".format(cls.count))

class User:
  count = 0

  def __init__(self, name, email, password):
        self.name = name
        self.email = email
        self.password = password

        User.count += 1
User.count = 5

# %%
def number_of_users(cls):
  print("총 유저 수는: {}입니다".format(User.count))

  number_of_users = classmethod(number_of_users)

# %%
class MenuItem:
  def __init__(self, name, price):
    self.name = name
    self.price = price

  def __str__(self):
          return "{} 가격: {}".format(self.name, self.price)


  # 메뉴 인스턴스 생성
burger = MenuItem("햄버거", 4000)
coke = MenuItem("콜라", 1500)
fries = MenuItem("후렌치 후라이", 1500)

# 메뉴 인스턴스 출력
print(burger)
print(coke)
print(fries)
# Out:
# 햄버거 가격: 4000
# 콜라 가격: 1500
# 후렌치 후라이 가격: 1500

# %%
class GameCharacter:
    # 게임 캐릭터 클래스
    def __init__(self, name, hp, power):
        # 게임 캐릭터는 속성으로 이름, hp, 공격력을 갖는다
        self.name = name
        self.hp = hp
        self.power = power


    def is_alive(self):
        # 게임 캐릭터가 아직 살아있는지(체력이 0이 넘는지) 확인하는 메소드
        return self.hp > 0


    def get_attacked(self, damage):
        """
        게임 캐릭터가 살아있으면 공격한 캐릭터의 공격력만큼 체력을 깎는 메소드
        조건:
            1. 이미 캐릭터가 죽었으면 죽었다는 메시지를 출력한다
            2. 남은 체력보다 공격력이 더 크면 남은 체력은 0이 된다
        """
        if self.is_alive():
            self.hp = self.hp - damage if self.hp >= damage else 0
        else:
            print("{}님은 이미 죽었습니다.".format(self.name))


    def attack(self, other_character):
        # 게임 캐릭터가 살아있으면 파라미터로 받은 다른 캐릭터의 체력을 자신의 공격력만큼 깍는다.
        if self.is_alive():
            other_character.get_attacked(self.power)


    def __str__(self):
           # 게임 캐릭터의 의미있는 정보를 포함한 문자열을 리턴한다.
           return self.name + "님의 hp는 " + str(self.hp) + "만큼 남았습니다."


# 게임 캐릭터 인스턴스 생성
character_1 = GameCharacter("Ww영훈전사wW", 200, 30)
character_2 = GameCharacter("Xx지웅최고xX", 100, 50)

# 게임 캐릭터 인스턴스들 서로 공격
character_1.attack(character_2)
character_2.attack(character_1)
character_2.attack(character_1)
character_2.attack(character_1)
character_2.attack(character_1)
character_2.attack(character_1)

# 게임 캐릭터 인스턴스 출력
print(character_1)
print(character_2)
# Out:
# Ww영훈전사wW님은 이미 죽었습니다.
# Ww영훈전사wW님의 hp는 0만큼 남았습니다.
# Xx지웅최고xX님의 hp는 70만큼 남았습니다.

# %%
class Counter:
  def __init__(self, number=0):
    self.__number = number

  def reset(self):
    self.__number = 0

  def increment(self):
    self.__number += 1

  def get(self):
    return self.__number
