# %% [markdown]
# ### 파이썬 프로그래밍 핵심 개념
#
# ---
# 1. 숫자형
# - 덧셈(+), 뺄셈(-), 나머지(/), 거듭제곱(**)
# - #floor division (버림 나눗셈)
# - print(7 // 2)
# - round(반올림)
#
# 나눗셈은 항상 소수형으로 나옴
#
# 2. 문자열(String)
# - 큰따옴표, 작은따옴표 : 완전 동일한 문자
# - 문자열 연결 String concatenation
# - 역슬래시를 써줘야 오류없이 출력
#
# 3. 형 변환(Type Conversion) : 논리적으로 이루어지는가?
# - 정수형으로 변환 int
# - 실수형으로 변환 float
# - 문자열로 변환 str
#
# 4. format을 이용한 문자열 포매팅
# - .format(변수1, 변수2, 변수3)
#
# 5. 불 대수 값 : 진리 값(True or False)
# - 일상적인 논리를 수학적으로 표현한 것
# - AND OR NOT : 참 또는 거짓이 확실한 문장
# - 참과 거짓을 표현하는 자료형 = 불린형
#
# 6. Type 함수
# - 어떤 자료형인지 알수 있게 해주는 타입함수
# - type(자료형)

# %% [markdown]
# 1. 변수 제대로 이해하기
# - 파이썬에서 등호 연산자의 의미  : 같다가 아닌 지정해주는 것
#
# 2. 함수의 실행 순서
# - 실행한다 = 함수를 호출한다
#
# 3. return문 이해하기
# - 무언가를 돌려주는 것(함수가)
# - 값 돌려주기, 함수 즉시 종료하기(dead code)
#
# 4. return과 print의 차이
# - return은 값을 반환
# - print는 None을 반환
#
# 5. Scope(범위)
# - 함수 내에서 정의한 변수 = 지역변수
# - 지역변수는 함수내에서만 이용 가능
# - 함수 밖에서 변수를 정의한 경우 = 글로벌 변수(모든 곳에서 사용가능)
# - 파라미터 또한 로컬변수(지역변수)라고 할 수 있다
# - 모든 변수에는 사용 가능한 범위가 있다
#
# 6. 상수(constant)
# - 절대로 바뀌지 않는 수
# - 대문자로 표기
# - 일반변수와 상수를 구분짓기 위함
#
# 7. 스타일 : 주관적인 것
# - 가독성을 높이는 스타일 : 이해하기 쉬움
# - 주석을 이용하여 가독성을 높이기
#
# 8. while 반복문
# - 반복적인 일을 시킬 때
# - while 조건 부문:
#
#     수행 부분
#
# 9. if문 개념
# - 만약 if
# - 그렇지 않으면 else
#
# 10. elif 문

# %%
ㄹㄹprint(2*3+2)
print(7//2)
print(8//3)
print(round(1.4))
print(round(1.6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-d6ba095cb02a> in <cell line: 1>()
# ----> 1 ㄹㄹprint(2*3+2)
#       2 print(7//2)
#       3 print(8//3)
#       4 print(round(1.4))
#       5 print(round(1.6))
#
# NameError: name 'ᄅᄅprint' is not defined

# %%
"안녕" * 3
# Out:
# '안녕안녕안녕'

# %%
year = 2024

print("안녕"+"하세요")
# Out:
# 안녕하세요

# %%
year = 2024
month = 12
day = 24

print("오늘은 {}년 {}월 {}일 입니다".format(year, month, day))
# Out:
# 오늘은 2024년 12월 24일 입니다

# %%
print("저는 {1}, {0}, {2}를 먹는다".format("빵", "곱", "껌"))
# Out:
# 저는 곱, 빵, 껌를 먹는다

# %%
name = "최지웅"
age = 32

print("제 이름은 %s이고 %d살입니다." % (name, age))
# Out:
# 제 이름은 최지웅이고 32살입니다.

# %%
name = "최지웅"
age = 32

print("제 이름은 {}이고 {}살입니다.".format(name, age))
# Out:
# 제 이름은 최지웅이고 32살입니다.

# %%
name = "최지웅"
age = 32

print(f"제 이름은 {name}이고 {age}살입니다.")
# Out:
# 제 이름은 최지웅이고 32살입니다.
