# %% [markdown]
# 1. 모듈
# - 미리 만들어져있는 많은 모듈들
# - 코드를 파일 단위로 나누어 저장
# - 파일 하나를 모듈이라 정의
# - 코드를 재사용
#
#     - 사용 방법
#     - from 모듈이름 import 함수이름
#     - 별명 짓기, import 모듈이름 as 벌명
#     - 모든 내용 가져오기, from 모듈이름 import *
#
#
# 2. 내장함수 : dir
# - print(dir(area))
#
#
# 3. 특수변수(던더 : 더블 언더 스코어)
# - 던더파일
#
# 4. 네임스페이스
#
#
# 5. 스탠다드 라이브러리
# -  int, float, stirng같은 자료형
# - print, dir 같은 내장 함수
# - 유용한 기능을 제공하는 모듈들
#
# 6. 모듈 검색 경로
# - import sys.path / .append()
#
# 7. 스크립트 vs 모듈
# - 스크립트 : 프로그램을 작동시키는 코드를 담은 실행 용도의 파일
# - 모듈 : 프로그램에 필요한 변수들이나 함수들을 정의해 놓은 파일
#
# 8. 모듈을 스크립트로 사용해 보기
#
#
# 9. __name__ 특수변수(던더 네임)
# - 모듈의 이름을 저장해놓은 변수
# - __name__의 값은 파이썬이 알아서 정해줌
# - 직접 실행하면 __name__은 __main__으로 설정
# - 파일을 임포트하면 __name__은 모듈 이름으로 설정
#
#
# ##### 패키지
# 1. 패키지
# - 모듈을 묶어놓은 것
# - 구성요소 잘 정리 재활용
#
# 2. 패키지 만들기
# - 프로젝트 폴더에서 디렉토리(폴더) 만들기
# - __init__이라는 파일 만들기
#
# 3. 패키지 사용하기
# - import 사용하여 모듈과 똑같이 사용
#
# 4. __init__ 파일 : 패키지 초기화
# - 이니셜라이즈 줄인것 : 초기화
#
# 5. __init__ 파일에서 모듈 임포트하기
# 6. __init__파일에서 변수 정의하기
# - 패키지의 이닛파일에서 한번에 정의하는 것
#
# 7. __all__ 특수 변수
# - 이닛파일안에 __all__특수변수 사용하기
# - 리스트안에 문자열로 저장, 가져올것들을 저장
#
# 8. 서브패키지
# - 패키지 안의 패키지 : 서브패키지
# - 파이썬 패키지 : 자동으로 이닛 생성
# - from 패키지이름.서브패키지 이름 import 파일 이름
#
# 9. 상대 경로 임포트
# - 임포트하려는 위치를 상대적으로 임포트하는 것
#
# 10. 절대 경로 임포트
# - 임포트하려는 것을 다 풀어서 써주는 것
#
# #### 모듈과 패키지
#
# - 파이썬에 잘 만들어진 패키지들
# - 테이블 형식으로 만들어주는 : 판다스
#
# 11. 외부 패키지 사용법
# - 패키지에 어떤 함수들이 있는지
# - 패키지의 함수들이 무엇을 하는지
#
# 12. PyPI : 공식 패키지 저장소
# - pip 설치
#
# 13. PyCharm으로 외부 패키지 설치하기(Windows)
#
# 14. 파이썬의 가장 대표적인 패키지들
# - 데이터 분석 & 분석화
#     - numpy
#     - pandas
#     - matplotlob
#     - seaborn
#     - sklearn
# - 머신러닝
#     - sklearn
#     - tensorflow, pytorch, keras
#     - nltk
# - 앱 개발
#     - django
#     - flask

# %%
# PI = 3.14


# def circle(raduius):
  # PI * radius * radius


# def square(length):
  # length * length


## import area

## print(area.circle(10))
## print(area.square(10))

# %%
from math import log10, cos

log10(3)
cos(4)
# Out:
# -0.6536436208636119
