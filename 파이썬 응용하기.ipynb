# %% [markdown]
# 데이터 프로그래밍 by Python
#
#
# ---
#
# 파이썬 응용하기
#
#
# ---
#
# 리스트 정렬
# - sorted : 기존 리스트는 건드리지 않고, 정렬된 새로운 리스트를 리턴
# - sort : 아무것도 리턴하지 않고 기존 리스트를 정렬
#
# for 반복문
# - 상황에 따라 더 깔끔하게 보일수가 있음
# - while문과는 다르게 조건 부분이 없음
#
# range() 함수
# - for i in range(1, 10, 1) : 1부터 10까지 정수를 출력
# - range(Start, Stop, Step)
# - 간편, 깔끔, 메모리 효율성
#
# 사전 dictionary{}
# - key : value(키와 값)
# - in 사전안에 원하는 것이 있는지 확인
# - items() 키와 값을 한번에 출력
#
# 앨리어싱 Aliasing
# - 값에 변수를 저장하면 이름표를 달아주는 것
# - 이름표는 변수 한곳에만 달릴 수 있음
# - list()함수 새로운 리스트를 생성
#
# 리스트와 문자열
# - 리스트 슬라이싱[Start, Stop, Step]
#
# 모듈 ex) 넘파이, 판다스
# - 다양한 함수들의 집합?
# - import, from...import,
#
# 스탠다드 라이브러리 ex) math, random, datetime
# - 표준 라이브러리 : 다양한 모듈들(기능들)
#
# input 함수
# - 사용자입력을 받기 위한 함수
# - int(input()) 문자열을 정수형으로 변환
#
# 파일읽기
# - with open('파일이름.txt', 'r') as f:
#   - for line in f:
#     - print(line)
#
# strip
# - 화이트 스페이스를 없애줌
# - ex) "     avc           dsd sdsds        sd"
#
# split
# - ex) split('.') .를 기준으로 문자열을 나누기
#
# - ex) full_name = "Kim, Yuna"
# -print(full_name.split(", ")) = ['Kim', 'Yuna']
#
# 파일쓰기
# - with open('new_file.txt', 'w') as f:
# - f.wirte("sdafjsklfjakl")

# %%
num = [1,2,3,4,5,6,7,8,9]
num[:4:-1]
# Out:
# [9, 8, 7, 6]

# %%
from random import randint


def generate_numbers():
    numbers = []

    while len(numbers) < 3:
        num = randint(0, 9)
        if num not in numbers:
            numbers.append(num)

    print("0과 9 사이의 서로 다른 숫자 3개를 랜덤한 순서로 뽑았습니다.\n")
    return numbers


# 테스트 코드
print(generate_numbers())
# Out:
# 0과 9 사이의 서로 다른 숫자 3개를 랜덤한 순서로 뽑았습니다.
#
# [7, 6, 4]

# %%
def take_guess():
    print("숫자 3개를 하나씩 차례대로 입력하세요.")

    new_guess = []
    while len(new_guess) < 3:
        new_num = int(input("{}번째 숫자를 입력하세요: ".format(len(new_guess) + 1)))

        if new_num < 0 or new_num > 9:
            print("범위를 벗어나는 숫자입니다. 다시 입력하세요.")
        elif new_num in new_guess:
            print("중복되는 숫자입니다. 다시 입력하세요.")
        else:
            new_guess.append(new_num)

    return new_guess


# 테스트 코드
print(take_guess())
# Out:
# 숫자 3개를 하나씩 차례대로 입력하세요.
# 1번째 숫자를 입력하세요: 4
# 2번째 숫자를 입력하세요: 5
# 3번째 숫자를 입력하세요: 6
# [4, 5, 6]

# %%
def get_score(guesses, solution):
    strike_count = 0
    ball_count = 0

    for i in range(3):
        if guesses[i] == solution[i]:
            strike_count += 1
        elif guesses[i] in solution:
            ball_count += 1

    return strike_count, ball_count


# 테스트 코드
s_1, b_1 = get_score([2, 7, 4], [2, 4, 7])
print(s_1, b_1)

s_2, b_2 = get_score([7, 2, 4], [2, 4, 7])
print(s_2, b_2)

s_3, b_3 = get_score([0, 4, 7], [2, 4, 7])
print(s_3, b_3)

s_4, b_4 = get_score([2, 4, 7], [2, 4, 7])
print(s_4, b_4)
# Out:
# 1 2
# 0 3
# 2 0
# 3 0

# %%
from random import randint


def generate_numbers():
    numbers = []

    while len(numbers) < 3:
        new_number = randint(0, 9)
        if new_number not in numbers:
            numbers.append(new_number)

    return numbers


def take_guess():
    new_guess = []
    while len(new_guess) < 3:
        num = int(input("{}번째 수를 입력하세요: ".format(len(new_guess) + 1)))

        if num < 0 or num > 9:
            print("0에서 9까지의 수를 입력해 주세요!")
        elif num in new_guess:
            print("중복되는 숫자입니다. 다시 입력하세요.")
        else:
            new_guess.append(num)

    return new_guess


def get_score(guesses, solution):
    strike_count = 0
    ball_count = 0

    for i in range(3):
        if guesses[i] == solution[i]:
            strike_count += 1
        elif guesses[i] in solution:
            ball_count += 1

    return strike_count, ball_count


# 여기서부터 게임 시작!
ANSWER = generate_numbers()
tries = 0

while True:
    user_guess = take_guess()
    s, b = get_score(user_guess, ANSWER)

    print("{}S {}B\n".format(s, b))
    tries += 1

    if s == 3:
        break

print("축하합니다. {}번 만에 세 숫자의 값과 위치를 모두 맞히셨습니다.".format(tries))
# Out:
# 1번째 수를 입력하세요: 7
# 2번째 수를 입력하세요: 8
# 3번째 수를 입력하세요: 9
# 0S 2B
#
# 1번째 수를 입력하세요: 8
# 2번째 수를 입력하세요: 9
# 3번째 수를 입력하세요: 7
# 1S 1B
#
# 1번째 수를 입력하세요: 8
# 2번째 수를 입력하세요: 9
# 3번째 수를 입력하세요: 5
# 0S 1B
#
# 1번째 수를 입력하세요: 9
# 2번째 수를 입력하세요: 5
# 3번째 수를 입력하세요: 7
# 2S 0B
#
# 1번째 수를 입력하세요: 9
# 2번째 수를 입력하세요: 3
# 3번째 수를 입력하세요: 7
# 3S 0B
#
# 축하합니다. 5번 만에 세 숫자의 값과 위치를 모두 맞히셨습니다.

# %%
735
